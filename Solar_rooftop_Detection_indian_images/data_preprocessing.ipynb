# %%
import os
import shutil

# %%
len(os.listdir("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/Solar_rooftop_Detection_indian_images/Easy_moderate_data/original/train/images"))
# Out:
# 1006

# %%
len(os.listdir("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/Solar_rooftop_Detection_indian_images/Easy_moderate_data/original/train/masks"))
# Out:
# 1006

# %%
len(os.listdir('/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/Solar_rooftop_Detection_indian_images/Easy_moderate_data/augmented/test/masks'))
# Out:
# 1200

# %%
# Set the source and destination folder paths
source_folder = '/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/Solar_rooftop_Detection_indian_images/final-moderate/augmented/test/masks'
destination_folder = '/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/Solar_rooftop_Detection_indian_images/Easy_moderate_data/augmented/test/masks'

# Create destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

# Loop through all files in the source folder
for filename in os.listdir(source_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):  # Add more extensions if needed
        src_file = os.path.join(source_folder, filename)
        dst_file = os.path.join(destination_folder, filename)
        shutil.copy(src_file, dst_file)
        print(f"Copied: {filename}")

print("All images copied successfully.")
# Out:
# Copied: vertical_flip_moderate_mask_86.png
# Copied: vertical_flip_moderate_mask_63.png
# Copied: original_moderate_mask_17.png
# Copied: vertical_flip_moderate_mask_81.png
# Copied: original_moderate_mask_82.png
# Copied: vertical_flip_moderate_mask_19.png
# Copied: horizontal_flip_moderate_mask_22.png
# Copied: vertical_flip_moderate_mask_47.png
# Copied: vertical_flip_moderate_mask_38.png
# Copied: horizontal_flip_moderate_mask_37.png
# Copied: rotate_90_clockwise_moderate_mask_97.png
# Copied: upside_down_moderate_mask_66.png
# Copied: horizontal_flip_moderate_mask_23.png
# Copied: vertical_flip_moderate_mask_48.png
# Copied: vertical_flip_moderate_mask_68.png
# Copied: upside_down_moderate_mask_82.png
# Copied: rotate_90_counterclockwise_moderate_mask_11.png
# Copied: original_moderate_mask_29.png
# Copied: horizontal_flip_moderate_mask_71.png
# Copied: original_moderate_mask_36.png
# Copied: rotate_90_counterclockwise_moderate_mask_70.png
# ...
