# %% [markdown]
# ## YOLOv10 + SAM

# %%
import os
os.getcwd()
os.chdir("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection")

# %%
import torch
import cv2
import pandas as pd
import numpy as np
from segment_anything import SamPredictor, sam_model_registry
from ultralytics import YOLO
import os 
from Solar_Rooftop_Detection.accuracy import compute_metrics
from Solar_Rooftop_Detection.generate_isolated_masks import generate_isolated_mask

# %%
# Load YOLO model 
yolo_model = YOLO("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/yolov10/best.pt")

# Load SAM model 
sam = sam_model_registry["vit_b"]("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/sam_check_point/Final_Models/FineTune_model_0_epoch_28_01_05_2025.pth")
sam.to("cuda")
sam_predictor = SamPredictor(sam)

data_folder = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images"
mask_folder = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/masks"
csv_path = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/results/sam/YOLOv10_SAM.csv"
os.makedirs(os.path.dirname(csv_path), exist_ok=True)

results_data = []

for img_name in os.listdir(data_folder):
    
    img_path = os.path.join(data_folder, img_name)
    image = cv2.imread(img_path)
    
    yolo_results = yolo_model.predict(img_path, conf=0.5, device="cuda")
    boxes = yolo_results[0].boxes.xyxy.cpu().numpy()
    
    mask_path = os.path.join(mask_folder, img_name)
    gt_mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    gt_mask = torch.from_numpy(gt_mask).to("cuda")  # Convert to torch tensor on GPU
    
    sam_predictor.set_image(image)
    
    for box in boxes:
        x1, y1, x2, y2 = map(int, box)
        
        isolated_mask = generate_isolated_mask(gt_mask, [x1, y1, x2, y2])
        
        masks, _, _ = sam_predictor.predict(box=np.array([x1, y1, x2, y2]))
            
        pred_mask = masks[0]
        pred_mask = torch.from_numpy(masks[0]).to("cuda") 
        metrics = compute_metrics(pred_mask, isolated_mask)

        results_data.append(metrics)
        
metrics_df = pd.DataFrame(results_data, columns=["pixel_iou", "pixel_dice", "pixel_accuracy", "pixel_precision", "pixel_recall", "region_iou", "region_dice", "region_precision", "region_recall", "region_success_accuracy"])
metrics_df.to_csv(csv_path, index=False)
# Out:
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_3.png: 1024x1024 1 road, 2.3ms
# Speed: 1.9ms preprocess, 2.3ms inference, 7.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_1.png: 1024x1024 1 road, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_3.png: 1024x1024 (no detections), 2.6ms
# Speed: 1.3ms preprocess, 2.6ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_2.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.9ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_4.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_2.png: 1024x1024 1 road, 2.5ms
# Speed: 1.6ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_3.png: 1024x1024 2 roads, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_3.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_1.png: 1024x1024 2 roads, 2.5ms
# Speed: 1.2ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_4.png: 1024x1024 1 road, 2.4ms
# Speed: 1.8ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_4.png: 1024x1024 2 roads, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_2.png: 1024x1024 1 road, 2.6ms
# Speed: 1.2ms preprocess, 2.6ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_3.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_1.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_3.png: 1024x1024 2 roads, 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_3.png: 1024x1024 1 road, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_2.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_3.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_4.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_4.png: 1024x1024 1 road, 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_3.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_1.png: 1024x1024 1 road, 2.3ms
# Speed: 1.5ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_3.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_1.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_1.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_2.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.8ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_1.png: 1024x1024 (no detections), 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_3.png: 1024x1024 1 road, 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_2.png: 1024x1024 (no detections), 2.7ms
# Speed: 1.2ms preprocess, 2.7ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_3.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_4.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_1.png: 1024x1024 1 road, 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_2.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_3.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_2.png: 1024x1024 1 road, 2.7ms
# Speed: 1.3ms preprocess, 2.7ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_3.png: 1024x1024 2 roads, 2.4ms
# Speed: 1.4ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_1.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_3.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_1.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.4ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_3.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_3.png: 1024x1024 (no detections), 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_2.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_1.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_4.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_4.png: 1024x1024 (no detections), 2.6ms
# Speed: 1.5ms preprocess, 2.6ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_2.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_4.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_2.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_2.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_3.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_3.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_4.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_1.png: 1024x1024 1 road, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_1.png: 1024x1024 (no detections), 2.5ms
# Speed: 1.7ms preprocess, 2.5ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_3.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_4.png: 1024x1024 2 roads, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_3.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_2.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_3.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_2.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.9ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_4.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_2.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_4.png: 1024x1024 2 roads, 2.5ms
# Speed: 1.4ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_1.png: 1024x1024 1 road, 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_4.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.5ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_3.png: 1024x1024 2 roads, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_3.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_2.png: 1024x1024 1 road, 2.3ms
# Speed: 1.4ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.8ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_1.png: 1024x1024 2 roads, 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_2.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_1.png: 1024x1024 (no detections), 2.6ms
# Speed: 1.2ms preprocess, 2.6ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_4.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_1.png: 1024x1024 1 road, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_2.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.9ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_3.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_4.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_4.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.4ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_4.png: 1024x1024 3 roads, 2.6ms
# Speed: 1.2ms preprocess, 2.6ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_2.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_2.png: 1024x1024 2 roads, 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_4.png: 1024x1024 (no detections), 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_3.png: 1024x1024 1 road, 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.7ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_4.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_1.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_1.png: 1024x1024 1 road, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_2.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_2.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.8ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_2.png: 1024x1024 (no detections), 2.5ms
# Speed: 1.8ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_1.png: 1024x1024 1 road, 2.1ms
# Speed: 1.2ms preprocess, 2.1ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_1.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_2.png: 1024x1024 1 road, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_2.png: 1024x1024 1 road, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_4.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.7ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_1.png: 1024x1024 (no detections), 2.6ms
# Speed: 1.3ms preprocess, 2.6ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_2.png: 1024x1024 1 road, 2.5ms
# Speed: 1.2ms preprocess, 2.5ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_4.png: 1024x1024 1 road, 2.4ms
# Speed: 1.4ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_4.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_3.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_3.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_1.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_4.png: 1024x1024 2 roads, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_3.png: 1024x1024 2 roads, 2.5ms
# Speed: 1.8ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_1.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_3.png: 1024x1024 (no detections), 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_2.png: 1024x1024 1 road, 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_2.png: 1024x1024 1 road, 2.5ms
# Speed: 1.8ms preprocess, 2.5ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_4.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_4.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_2.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_3.png: 1024x1024 1 road, 2.4ms
# Speed: 1.8ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_1.png: 1024x1024 1 road, 2.3ms
# Speed: 1.8ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_2.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_3.png: 1024x1024 1 road, 2.7ms
# Speed: 1.2ms preprocess, 2.7ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_1.png: 1024x1024 (no detections), 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_2.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_3.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_1.png: 1024x1024 1 road, 2.6ms
# Speed: 1.3ms preprocess, 2.6ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_1.png: 1024x1024 1 road, 2.3ms
# Speed: 1.9ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_3.png: 1024x1024 2 roads, 2.4ms
# Speed: 1.8ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_3.png: 1024x1024 2 roads, 2.4ms
# Speed: 1.8ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_2.png: 1024x1024 1 road, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_2.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.7ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_3.png: 1024x1024 1 road, 2.7ms
# Speed: 1.2ms preprocess, 2.7ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_2.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_3.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_4.png: 1024x1024 (no detections), 2.5ms
# Speed: 1.2ms preprocess, 2.5ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_2.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_4.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_3.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_2.png: 1024x1024 (no detections), 2.6ms
# Speed: 1.8ms preprocess, 2.6ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.4ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_4.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_1.png: 1024x1024 1 road, 2.7ms
# Speed: 1.3ms preprocess, 2.7ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_4.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.8ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_2.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_2.png: 1024x1024 3 roads, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_1.png: 1024x1024 2 roads, 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_2.png: 1024x1024 2 roads, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_2.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_3.png: 1024x1024 1 road, 2.3ms
# Speed: 2.0ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_3.png: 1024x1024 1 road, 2.4ms
# Speed: 1.8ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_4.png: 1024x1024 1 road, 2.5ms
# Speed: 1.9ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_3.png: 1024x1024 1 road, 2.5ms
# Speed: 1.2ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_4.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_2.png: 1024x1024 1 road, 2.4ms
# Speed: 1.8ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_2.png: 1024x1024 1 road, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_3.png: 1024x1024 1 road, 2.3ms
# Speed: 1.8ms preprocess, 2.3ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.8ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_3.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.8ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_1.png: 1024x1024 1 road, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_4.png: 1024x1024 1 road, 2.3ms
# Speed: 1.3ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_4.png: 1024x1024 1 road, 2.6ms
# Speed: 1.2ms preprocess, 2.6ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_1.png: 1024x1024 2 roads, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_3.png: 1024x1024 (no detections), 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_2.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_4.png: 1024x1024 (no detections), 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_4.png: 1024x1024 1 road, 2.2ms
# Speed: 1.2ms preprocess, 2.2ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_2.png: 1024x1024 (no detections), 2.4ms
# Speed: 1.4ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_2.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_2.png: 1024x1024 1 road, 2.3ms
# Speed: 1.8ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_1.png: 1024x1024 1 road, 2.6ms
# Speed: 1.3ms preprocess, 2.6ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_3.png: 1024x1024 2 roads, 2.4ms
# Speed: 1.8ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_3.png: 1024x1024 2 roads, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_1.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_3.png: 1024x1024 1 road, 2.4ms
# Speed: 1.2ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_2.png: 1024x1024 1 road, 2.5ms
# Speed: 1.2ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_3.png: 1024x1024 1 road, 2.4ms
# Speed: 1.7ms preprocess, 2.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_4.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_4.png: 1024x1024 (no detections), 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_1.png: 1024x1024 1 road, 2.3ms
# Speed: 1.2ms preprocess, 2.3ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_1.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_2.png: 1024x1024 2 roads, 2.5ms
# Speed: 1.2ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_3.png: 1024x1024 1 road, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_2.png: 1024x1024 1 road, 2.4ms
# Speed: 1.3ms preprocess, 2.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)

# %%
import pandas as pd
metrics_df = pd.read_csv("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/results/sam/YOLOv10_SAM.csv")
metrics_df.head(5)
metrics_df.mean()
# Out:
# pixel_iou                  0.103619
# pixel_dice                 0.180173
# pixel_accuracy             0.636502
# pixel_precision            0.108429
# pixel_recall               0.856265
# region_iou                 0.103619
# region_dice                0.180173
# region_precision           0.108429
# region_recall              0.856265
# region_success_accuracy    0.000000
# dtype: float64

# %% [markdown]
# ## YOLOv11 + SAM

# %%
import os
os.getcwd()
os.chdir("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection")

import torch
import cv2
import pandas as pd
import numpy as np
from segment_anything import SamPredictor, sam_model_registry
from ultralytics import YOLO
import os 
from Solar_Rooftop_Detection.accuracy import compute_metrics
from Solar_Rooftop_Detection.generate_isolated_masks import generate_isolated_mask

# %%
# Load YOLO model 
yolo_model = YOLO("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/yolov11/best.pt")

# Load SAM model 
sam = sam_model_registry["vit_b"]("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/sam_check_point/Final_Models/FineTune_model_0_epoch_28_01_05_2025.pth")
sam.to("cuda")
sam_predictor = SamPredictor(sam)

data_folder = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images"
mask_folder = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/masks"
csv_path = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/results/sam/YOLOv11_SAM.csv"
os.makedirs(os.path.dirname(csv_path), exist_ok=True)

results_data = []

for img_name in os.listdir(data_folder):
    
    img_path = os.path.join(data_folder, img_name)
    image = cv2.imread(img_path)
    
    yolo_results = yolo_model.predict(img_path, conf=0.5, device="cuda")
    boxes = yolo_results[0].boxes.xyxy.cpu().numpy()
    
    mask_path = os.path.join(mask_folder, img_name)
    gt_mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    gt_mask = torch.from_numpy(gt_mask).to("cuda")  # Convert to torch tensor on GPU
    
    sam_predictor.set_image(image)
    
    for box in boxes:
        x1, y1, x2, y2 = map(int, box)
        
        isolated_mask = generate_isolated_mask(gt_mask, [x1, y1, x2, y2])
        
        masks, _, _ = sam_predictor.predict(box=np.array([x1, y1, x2, y2]))
            
        pred_mask = masks[0]
        pred_mask = torch.from_numpy(masks[0]).to("cuda") 
        metrics = compute_metrics(pred_mask, isolated_mask)

        results_data.append(metrics)
        
metrics_df = pd.DataFrame(results_data, columns=["pixel_iou", "pixel_dice", "pixel_accuracy", "pixel_precision", "pixel_recall", "region_iou", "region_dice", "region_precision", "region_recall", "region_success_accuracy"])
metrics_df.to_csv(csv_path, index=False)
# Out:
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_3.png: 1024x1024 1 road, 3.3ms
# Speed: 1.3ms preprocess, 3.3ms inference, 20.0ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_3.png: 1024x1024 1 road, 3.0ms
# Speed: 1.3ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_4.png: 1024x1024 1 road, 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_2.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.4ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_3.png: 1024x1024 1 road, 3.1ms
# Speed: 1.8ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_3.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_1.png: 1024x1024 2 roads, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_4.png: 1024x1024 1 road, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_4.png: 1024x1024 2 roads, 3.1ms
# Speed: 1.7ms preprocess, 3.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.4ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_4.png: 1024x1024 1 road, 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_1.png: 1024x1024 3 roads, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_3.png: 1024x1024 3 roads, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_3.png: 1024x1024 1 road, 3.2ms
# Speed: 1.4ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_2.png: 1024x1024 (no detections), 3.1ms
# Speed: 1.2ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_4.png: 1024x1024 3 roads, 2.8ms
# Speed: 1.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_4.png: 1024x1024 1 road, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_4.png: 1024x1024 1 road, 3.3ms
# Speed: 1.9ms preprocess, 3.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_3.png: 1024x1024 (no detections), 3.2ms
# Speed: 1.3ms preprocess, 3.2ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_1.png: 1024x1024 1 road, 3.3ms
# Speed: 1.2ms preprocess, 3.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_3.png: 1024x1024 1 road, 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_1.png: 1024x1024 1 road, 2.8ms
# Speed: 1.3ms preprocess, 2.8ms inference, 0.9ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_4.png: 1024x1024 1 road, 2.8ms
# Speed: 1.3ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_1.png: 1024x1024 1 road, 3.0ms
# Speed: 1.3ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_2.png: 1024x1024 1 road, 3.2ms
# Speed: 1.4ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_4.png: 1024x1024 1 road, 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_1.png: 1024x1024 1 road, 2.8ms
# Speed: 1.3ms preprocess, 2.8ms inference, 0.9ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_2.png: 1024x1024 2 roads, 3.1ms
# Speed: 1.2ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_3.png: 1024x1024 1 road, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_4.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.5ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_2.png: 1024x1024 2 roads, 3.0ms
# Speed: 1.3ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_3.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_1.png: 1024x1024 1 road, 3.1ms
# Speed: 1.8ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_3.png: 1024x1024 2 roads, 3.2ms
# Speed: 1.3ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_2.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_4.png: 1024x1024 1 road, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_4.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 1.0ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_1.png: 1024x1024 1 road, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_1.png: 1024x1024 2 roads, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_4.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_4.png: 1024x1024 (no detections), 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_4.png: 1024x1024 1 road, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_2.png: 1024x1024 2 roads, 3.2ms
# Speed: 1.8ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.9ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_1.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_4.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_1.png: 1024x1024 2 roads, 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_4.png: 1024x1024 2 roads, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_3.png: 1024x1024 (no detections), 3.1ms
# Speed: 1.8ms preprocess, 3.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_2.png: 1024x1024 1 road, 3.0ms
# Speed: 1.3ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_3.png: 1024x1024 1 road, 2.8ms
# Speed: 1.3ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_1.png: 1024x1024 1 road, 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_4.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_2.png: 1024x1024 1 road, 3.1ms
# Speed: 1.2ms preprocess, 3.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_4.png: 1024x1024 3 roads, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_1.png: 1024x1024 1 road, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_4.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_3.png: 1024x1024 2 roads, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_3.png: 1024x1024 1 road, 3.1ms
# Speed: 1.2ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_2.png: 1024x1024 2 roads, 3.1ms
# Speed: 1.9ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_1.png: 1024x1024 1 road, 3.1ms
# Speed: 1.8ms preprocess, 3.1ms inference, 0.9ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_1.png: 1024x1024 3 roads, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_2.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_1.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_4.png: 1024x1024 (no detections), 3.2ms
# Speed: 1.9ms preprocess, 3.2ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_1.png: 1024x1024 1 road, 3.2ms
# Speed: 1.4ms preprocess, 3.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_2.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_3.png: 1024x1024 2 roads, 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_4.png: 1024x1024 (no detections), 3.3ms
# Speed: 1.3ms preprocess, 3.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_4.png: 1024x1024 1 road, 2.9ms
# Speed: 1.4ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_4.png: 1024x1024 3 roads, 3.1ms
# Speed: 1.2ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_2.png: 1024x1024 2 roads, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_2.png: 1024x1024 2 roads, 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_4.png: 1024x1024 1 road, 3.0ms
# Speed: 1.4ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_3.png: 1024x1024 2 roads, 2.8ms
# Speed: 2.0ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_4.png: 1024x1024 1 road, 2.9ms
# Speed: 1.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_4.png: 1024x1024 (no detections), 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.4ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.4ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_2.png: 1024x1024 1 road, 3.0ms
# Speed: 1.8ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.4ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_4.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.9ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_1.png: 1024x1024 1 road, 3.0ms
# Speed: 1.8ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_1.png: 1024x1024 1 road, 3.4ms
# Speed: 1.3ms preprocess, 3.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.4ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_4.png: 1024x1024 (no detections), 3.5ms
# Speed: 1.2ms preprocess, 3.5ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_1.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_2.png: 1024x1024 1 road, 2.8ms
# Speed: 1.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_4.png: 1024x1024 1 road, 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_4.png: 1024x1024 1 road, 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_3.png: 1024x1024 (no detections), 2.8ms
# Speed: 1.8ms preprocess, 2.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_3.png: 1024x1024 1 road, 2.8ms
# Speed: 1.3ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_4.png: 1024x1024 2 roads, 3.0ms
# Speed: 1.3ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_3.png: 1024x1024 2 roads, 2.8ms
# Speed: 1.3ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_1.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_3.png: 1024x1024 (no detections), 2.8ms
# Speed: 1.4ms preprocess, 2.8ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_2.png: 1024x1024 4 roads, 3.2ms
# Speed: 1.3ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_2.png: 1024x1024 1 road, 3.0ms
# Speed: 1.9ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_4.png: 1024x1024 (no detections), 3.0ms
# Speed: 1.3ms preprocess, 3.0ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_4.png: 1024x1024 1 road, 2.8ms
# Speed: 1.4ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_4.png: 1024x1024 1 road, 2.9ms
# Speed: 1.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_2.png: 1024x1024 1 road, 3.0ms
# Speed: 1.4ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_3.png: 1024x1024 1 road, 2.8ms
# Speed: 1.3ms preprocess, 2.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_1.png: 1024x1024 1 road, 3.1ms
# Speed: 1.7ms preprocess, 3.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_2.png: 1024x1024 2 roads, 3.2ms
# Speed: 1.9ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_3.png: 1024x1024 2 roads, 2.8ms
# Speed: 1.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_1.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.6ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_2.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_3.png: 1024x1024 1 road, 3.2ms
# Speed: 1.3ms preprocess, 3.2ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_1.png: 1024x1024 1 road, 2.8ms
# Speed: 1.1ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_1.png: 1024x1024 1 road, 3.1ms
# Speed: 1.2ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_3.png: 1024x1024 2 roads, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_3.png: 1024x1024 1 road, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_1.png: 1024x1024 1 road, 3.3ms
# Speed: 1.3ms preprocess, 3.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_2.png: 1024x1024 1 road, 3.1ms
# Speed: 1.2ms preprocess, 3.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.4ms preprocess, 2.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_3.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_3.png: 1024x1024 1 road, 2.8ms
# Speed: 1.1ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_4.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.7ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_2.png: 1024x1024 (no detections), 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_4.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_3.png: 1024x1024 1 road, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_2.png: 1024x1024 1 road, 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_1.png: 1024x1024 1 road, 2.8ms
# Speed: 1.3ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_4.png: 1024x1024 1 road, 2.8ms
# Speed: 1.7ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_1.png: 1024x1024 1 road, 2.8ms
# Speed: 1.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_4.png: 1024x1024 1 road, 3.1ms
# Speed: 1.2ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_4.png: 1024x1024 1 road, 2.8ms
# Speed: 1.1ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_2.png: 1024x1024 1 road, 2.8ms
# Speed: 1.7ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_2.png: 1024x1024 3 roads, 3.0ms
# Speed: 1.9ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_2.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_2.png: 1024x1024 3 roads, 3.0ms
# Speed: 1.7ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_3.png: 1024x1024 3 roads, 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_4.png: 1024x1024 1 road, 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_4.png: 1024x1024 2 roads, 3.2ms
# Speed: 1.3ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_4.png: 1024x1024 1 road, 3.3ms
# Speed: 1.3ms preprocess, 3.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.4ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_2.png: 1024x1024 1 road, 6.3ms
# Speed: 3.3ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_3.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.7ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_4.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_1.png: 1024x1024 1 road, 3.3ms
# Speed: 1.2ms preprocess, 3.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_4.png: 1024x1024 1 road, 3.0ms
# Speed: 1.8ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_1.png: 1024x1024 3 roads, 2.9ms
# Speed: 1.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_3.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_4.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.6ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_4.png: 1024x1024 1 road, 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_2.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_2.png: 1024x1024 2 roads, 2.8ms
# Speed: 1.6ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_2.png: 1024x1024 1 road, 2.8ms
# Speed: 1.1ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_1.png: 1024x1024 1 road, 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_3.png: 1024x1024 1 road, 2.8ms
# Speed: 1.1ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_3.png: 1024x1024 2 roads, 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_3.png: 1024x1024 1 road, 2.9ms
# Speed: 1.7ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_2.png: 1024x1024 1 road, 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_3.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_4.png: 1024x1024 2 roads, 2.9ms
# Speed: 1.3ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_4.png: 1024x1024 (no detections), 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_1.png: 1024x1024 1 road, 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_1.png: 1024x1024 1 road, 2.8ms
# Speed: 1.6ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_2.png: 1024x1024 1 road, 2.8ms
# Speed: 1.1ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_3.png: 1024x1024 1 road, 2.8ms
# Speed: 1.3ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_2.png: 1024x1024 1 road, 2.8ms
# Speed: 1.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)

# %%
import pandas as pd
metrics_df = pd.read_csv("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/results/sam/YOLOv11_SAM.csv")
metrics_df.head(5)
metrics_df.mean()
# Out:
# pixel_iou                  0.117312
# pixel_dice                 0.193483
# pixel_accuracy             0.684393
# pixel_precision            0.124065
# pixel_recall               0.850125
# region_iou                 0.117312
# region_dice                0.193483
# region_precision           0.124065
# region_recall              0.850125
# region_success_accuracy    0.026316
# dtype: float64

# %% [markdown]
# # YOLOv12 + SAM

# %%
import os
os.getcwd()
os.chdir("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection")

import torch
import cv2
import pandas as pd
import numpy as np
from segment_anything import SamPredictor, sam_model_registry
from ultralytics import YOLO
import os 
from Solar_Rooftop_Detection.accuracy import compute_metrics
from Solar_Rooftop_Detection.generate_isolated_masks import generate_isolated_mask


# Load YOLO model 
yolo_model = YOLO("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/yolov12/best.pt")

# Load SAM model 
sam = sam_model_registry["vit_b"]("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/sam_check_point/Final_Models/FineTune_model_0_epoch_28_01_05_2025.pth")
sam.to("cuda")
sam_predictor = SamPredictor(sam)

data_folder = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images"
mask_folder = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/masks"
csv_path = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/results/sam/YOLOv12_SAM.csv"
os.makedirs(os.path.dirname(csv_path), exist_ok=True)

results_data = []

for img_name in os.listdir(data_folder):
    
    img_path = os.path.join(data_folder, img_name)
    image = cv2.imread(img_path)
    
    yolo_results = yolo_model.predict(img_path, conf=0.5, device="cuda")
    boxes = yolo_results[0].boxes.xyxy.cpu().numpy()
    
    mask_path = os.path.join(mask_folder, img_name)
    gt_mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    gt_mask = torch.from_numpy(gt_mask).to("cuda")  # Convert to torch tensor on GPU
    
    sam_predictor.set_image(image)
    
    for box in boxes:
        x1, y1, x2, y2 = map(int, box)
        
        isolated_mask = generate_isolated_mask(gt_mask, [x1, y1, x2, y2])
        
        masks, _, _ = sam_predictor.predict(box=np.array([x1, y1, x2, y2]))
            
        pred_mask = masks[0]
        pred_mask = torch.from_numpy(masks[0]).to("cuda") 
        metrics = compute_metrics(pred_mask, isolated_mask)

        results_data.append(metrics)
        
metrics_df = pd.DataFrame(results_data, columns=["pixel_iou", "pixel_dice", "pixel_accuracy", "pixel_precision", "pixel_recall", "region_iou", "region_dice", "region_precision", "region_recall", "region_success_accuracy"])
metrics_df.to_csv(csv_path, index=False)
# Out:
# FlashAttention is not available on this device. Using scaled_dot_product_attention instead.
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_3.png: 1024x1024 1 road, 4.4ms
# Speed: 1.8ms preprocess, 4.4ms inference, 49.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_1.png: 1024x1024 1 road, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_3.png: 1024x1024 1 road, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_2.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_1.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_4.png: 1024x1024 (no detections), 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_2.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_3.png: 1024x1024 2 roads, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_3.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_1.png: 1024x1024 2 roads, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_4.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_4.png: 1024x1024 1 road, 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_2.png: 1024x1024 1 road, 4.4ms
# Speed: 1.2ms preprocess, 4.4ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_3.png: 1024x1024 1 road, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_4.png: 1024x1024 2 roads, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_1.png: 1024x1024 1 road, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_3.png: 1024x1024 2 roads, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_3.png: 1024x1024 1 road, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_2.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.4ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_3.png: 1024x1024 (no detections), 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_4.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_4.png: 1024x1024 1 road, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_4.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_3.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_1.png: 1024x1024 2 roads, 11.1ms
# Speed: 2.8ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_3.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_1.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_4.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_1.png: 1024x1024 1 road, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_2.png: 1024x1024 1 road, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_4.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_1.png: 1024x1024 (no detections), 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_3.png: 1024x1024 1 road, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_1.png: 1024x1024 1 road, 4.3ms
# Speed: 1.3ms preprocess, 4.3ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_2.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_3.png: 1024x1024 1 road, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_4.png: 1024x1024 1 road, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_1.png: 1024x1024 1 road, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_2.png: 1024x1024 1 road, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_3.png: 1024x1024 1 road, 4.4ms
# Speed: 1.2ms preprocess, 4.4ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_2.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_3.png: 1024x1024 2 roads, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_1.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_3.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_1.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_3.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_3.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_2.png: 1024x1024 1 road, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_1.png: 1024x1024 1 road, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_4.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_4.png: 1024x1024 2 roads, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_1.png: 1024x1024 1 road, 4.4ms
# Speed: 1.2ms preprocess, 4.4ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_1.png: 1024x1024 2 roads, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_4.png: 1024x1024 1 road, 4.5ms
# Speed: 1.2ms preprocess, 4.5ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_4.png: 1024x1024 2 roads, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_2.png: 1024x1024 2 roads, 4.3ms
# Speed: 1.2ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_4.png: 1024x1024 1 road, 4.7ms
# Speed: 1.3ms preprocess, 4.7ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_2.png: 1024x1024 1 road, 4.2ms
# Speed: 1.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_2.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_3.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_3.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_1.png: 1024x1024 2 roads, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_4.png: 1024x1024 (no detections), 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_1.png: 1024x1024 1 road, 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_1.png: 1024x1024 1 road, 4.3ms
# Speed: 1.2ms preprocess, 4.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_3.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11728825_15_patch_4.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_3.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_2.png: 1024x1024 1 road, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_3.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_1.png: 1024x1024 2 roads, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_2.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_4.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_2.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_4.png: 1024x1024 3 roads, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_1.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_4.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_1.png: 1024x1024 1 road, 4.4ms
# Speed: 1.2ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_3.png: 1024x1024 1 road, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_3.png: 1024x1024 1 road, 4.4ms
# Speed: 1.2ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/15928855_15_patch_2.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_1.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_1.png: 1024x1024 3 roads, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_2.png: 1024x1024 (no detections), 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_1.png: 1024x1024 (no detections), 4.5ms
# Speed: 1.2ms preprocess, 4.5ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_4.png: 1024x1024 (no detections), 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_1.png: 1024x1024 1 road, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_2.png: 1024x1024 2 roads, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_3.png: 1024x1024 2 roads, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_4.png: 1024x1024 1 road, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_4.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.4ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_4.png: 1024x1024 3 roads, 4.3ms
# Speed: 1.2ms preprocess, 4.3ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_2.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_2.png: 1024x1024 2 roads, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_4.png: 1024x1024 2 roads, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_3.png: 1024x1024 1 road, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_4.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_4.png: 1024x1024 1 road, 4.3ms
# Speed: 1.2ms preprocess, 4.3ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_1.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_1.png: 1024x1024 1 road, 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_2.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_2.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_4.png: 1024x1024 1 road, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26278720_15_patch_2.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_1.png: 1024x1024 1 road, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_1.png: 1024x1024 (no detections), 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_2.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_2.png: 1024x1024 1 road, 4.3ms
# Speed: 1.2ms preprocess, 4.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_4.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_1.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_2.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_4.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_4.png: 1024x1024 2 roads, 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_3.png: 1024x1024 (no detections), 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_3.png: 1024x1024 1 road, 4.5ms
# Speed: 1.2ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_1.png: 1024x1024 (no detections), 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26428735_15_patch_4.png: 1024x1024 2 roads, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/25079170_15_patch_3.png: 1024x1024 1 road, 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_1.png: 1024x1024 (no detections), 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_3.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_2.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_2.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_4.png: 1024x1024 (no detections), 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_4.png: 1024x1024 1 road, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_4.png: 1024x1024 1 road, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26578720_15_patch_2.png: 1024x1024 (no detections), 4.1ms
# Speed: 1.4ms preprocess, 4.1ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_3.png: 1024x1024 (no detections), 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_1.png: 1024x1024 1 road, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_2.png: 1024x1024 1 road, 4.1ms
# Speed: 1.9ms preprocess, 4.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_3.png: 1024x1024 2 roads, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21779005_15_patch_1.png: 1024x1024 1 road, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/21479035_15_patch_2.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24779275_15_patch_3.png: 1024x1024 1 road, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_1.png: 1024x1024 1 road, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22078975_15_patch_1.png: 1024x1024 1 road, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_3.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_3.png: 1024x1024 2 roads, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_1.png: 1024x1024 1 road, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24029035_15_patch_2.png: 1024x1024 1 road, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10378780_15_patch_2.png: 1024x1024 (no detections), 4.6ms
# Speed: 1.2ms preprocess, 4.6ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22228900_15_patch_1.png: 1024x1024 1 road, 4.4ms
# Speed: 1.2ms preprocess, 4.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/10828720_15_patch_3.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_2.png: 1024x1024 1 road, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_3.png: 1024x1024 (no detections), 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428810_15_patch_4.png: 1024x1024 (no detections), 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878735_15_patch_2.png: 1024x1024 (no detections), 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_4.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18178780_15_patch_3.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_2.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_1.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_4.png: 1024x1024 1 road, 4.2ms
# Speed: 1.8ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328780_15_patch_1.png: 1024x1024 2 roads, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_4.png: 1024x1024 1 road, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478855_15_patch_4.png: 1024x1024 1 road, 4.3ms
# Speed: 1.2ms preprocess, 4.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22528885_15_patch_2.png: 1024x1024 1 road, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20728960_15_patch_2.png: 1024x1024 3 roads, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479170_15_patch_1.png: 1024x1024 2 roads, 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_2.png: 1024x1024 2 roads, 4.4ms
# Speed: 1.2ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_2.png: 1024x1024 3 roads, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_3.png: 1024x1024 1 road, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_3.png: 1024x1024 1 road, 4.3ms
# Speed: 1.8ms preprocess, 4.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_4.png: 1024x1024 1 road, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878885_15_patch_4.png: 1024x1024 2 roads, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328960_15_patch_3.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278915_15_patch_4.png: 1024x1024 1 road, 4.5ms
# Speed: 1.3ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478735_15_patch_2.png: 1024x1024 1 road, 4.1ms
# Speed: 1.4ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/17878780_15_patch_2.png: 1024x1024 1 road, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_3.png: 1024x1024 3 roads, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24628885_15_patch_1.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478900_15_patch_3.png: 1024x1024 (no detections), 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/16078870_15_patch_1.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22229050_15_patch_4.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11278840_15_patch_1.png: 1024x1024 1 road, 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_4.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24629200_15_patch_1.png: 1024x1024 3 roads, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/26878690_15_patch_3.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_2.png: 1024x1024 1 road, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23729020_15_patch_4.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.4ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23428540_15_patch_4.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_2.png: 1024x1024 1 road, 3.8ms
# Speed: 1.3ms preprocess, 3.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24479215_15_patch_2.png: 1024x1024 2 roads, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_2.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_1.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18478930_15_patch_3.png: 1024x1024 2 roads, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_3.png: 1024x1024 2 roads, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23278930_15_patch_1.png: 1024x1024 1 road, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20278885_15_patch_3.png: 1024x1024 (no detections), 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23429080_15_patch_2.png: 1024x1024 1 road, 4.0ms
# Speed: 1.1ms preprocess, 4.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/12328750_15_patch_3.png: 1024x1024 1 road, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/22529065_15_patch_4.png: 1024x1024 1 road, 3.8ms
# Speed: 1.3ms preprocess, 3.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18028750_15_patch_4.png: 1024x1024 (no detections), 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.2ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/23878540_15_patch_1.png: 1024x1024 1 road, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/20878930_15_patch_1.png: 1024x1024 1 road, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/24478825_15_patch_2.png: 1024x1024 2 roads, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/11128870_15_patch_3.png: 1024x1024 1 road, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# image 1/1 /home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images/18328735_15_patch_2.png: 1024x1024 1 road, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)

# %%
import pandas as pd
metrics_df = pd.read_csv("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/results/sam/YOLOv12_SAM.csv")
metrics_df.head(5)
metrics_df.mean()
# Out:
# pixel_iou                  0.114101
# pixel_dice                 0.190610
# pixel_accuracy             0.636438
# pixel_precision            0.120318
# pixel_recall               0.846898
# region_iou                 0.114101
# region_dice                0.190610
# region_precision           0.120318
# region_recall              0.846898
# region_success_accuracy    0.025907
# dtype: float64

# %% [markdown]
# # DETR + SAM

# %%
import os
os.getcwd()
os.chdir("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection")

import torch
import cv2
import pandas as pd
import numpy as np
from segment_anything import SamPredictor, sam_model_registry
from Solar_Rooftop_Detection.accuracy import compute_metrics
from Solar_Rooftop_Detection.generate_isolated_masks import generate_isolated_mask
from rfdetr import RFDETRBase
from PIL import Image
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746167255.807770  144650 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746167255.810310  144650 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746167255.816351  144650 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746167255.816359  144650 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746167255.816359  144650 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746167255.816360  144650 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Load SAM model
sam = sam_model_registry["vit_b"]("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/sam_check_point/Final_Models/FineTune_model_0_epoch_28_01_05_2025.pth")
sam.to("cuda")
sam_predictor = SamPredictor(sam)

data_folder = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/images"
mask_folder = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/ROAD_DATASET/test/masks"
csv_path = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/results/sam/DETR_SAM.csv"

results_data = []

checkpoint_path = "/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/detr/checkpoint_best_total.pth"  

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model_wrapper = RFDETRBase()

underlying_model = model_wrapper.model
underlying_model.reinitialize_detection_head(num_classes=2)

checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)

pytorch_model = underlying_model.model
pytorch_model.load_state_dict(checkpoint['model'])

pytorch_model.to(device)
pytorch_model.eval()

for img_name in os.listdir(data_folder):
    
    img_path = os.path.join(data_folder, img_name)
    image = cv2.imread(img_path)
    
    detections = model_wrapper.predict(image, threshold=0.5)
    boxes = detections.xyxy
    
    mask_path = os.path.join(mask_folder, img_name)
    gt_mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    gt_mask = torch.from_numpy(gt_mask).to("cuda")  # Convert to torch tensor on GPU
    
    sam_predictor.set_image(image)
    
    for box in boxes:
        x1, y1, x2, y2 = map(int, box)
        
        isolated_mask = generate_isolated_mask(gt_mask, [x1, y1, x2, y2])
        
        masks, _, _ = sam_predictor.predict(box=np.array([x1, y1, x2, y2]))
            
        pred_mask = masks[0]
        pred_mask = torch.from_numpy(masks[0]).to("cuda") 
        metrics = compute_metrics(pred_mask, isolated_mask)

        results_data.append(metrics)
        
metrics_df = pd.DataFrame(results_data, columns=["pixel_iou", "pixel_dice", "pixel_accuracy", "pixel_precision", "pixel_recall", "region_iou", "region_dice", "region_precision", "region_recall", "region_success_accuracy"])
metrics_df.to_csv(csv_path, index=False)
# Out:
# Loading pretrain weights
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)

# %%
metrics = pd.read_csv("/home/dhruv/Documents/DHRUV_SOLAR_ROOFTOP/solar_github/Solar_Rooftop_Detection/TRY_ON_OTHER_DATASET/COMPARISON_WITH_ROAD_SEGMENTATION/results/sam/DETR_SAM.csv")
output = metrics.mean(axis=0)
output
# Out:
# pixel_iou                  0.146798
# pixel_dice                 0.220483
# pixel_accuracy             0.761027
# pixel_precision            0.164171
# pixel_recall               0.824939
# region_iou                 0.146798
# region_dice                0.220483
# region_precision           0.164171
# region_recall              0.824939
# region_success_accuracy    0.075472
# dtype: float64
